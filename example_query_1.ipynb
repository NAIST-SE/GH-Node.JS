# %%
import json, glob, os, statistics as st

history_json_list = glob.glob(os.path.join('./dependencies_history', '*.json'))
oldest_version_list = dict()
for history_file in history_json_list:
    with open(history_file) as f: json_obj = json.loads(f.read())
    version_commit_time  = list(map(lambda version: (version, json_obj[version]['commit_time']), json_obj))
    oldest_version = sorted(version_commit_time, key=lambda tup: tup[0])[-1]
    oldest_version_list[history_file] = oldest_version
print(oldest_version_list)
# Out:
# {'./dependencies_history\\aaronthomas_aaronthomas.co.uk.json': ('1.0.1', 1535324932), './dependencies_history\\abramz_gulp-render-react.json': ('3.1.3', 1482123660), './dependencies_history\\adouglas_martian-robots.json': ('0.0.0', 1418592828), './dependencies_history\\aetheric_sockit.json': ('1.0.0', 1431381004), './dependencies_history\\Ahineya_jsdv.json': ('0.0.2-8', 1401383574), './dependencies_history\\akhoury_nodebb-plugin-import-xenforo.json': ('0.0.9', 1463854759), './dependencies_history\\alessioalex_git-count-files.json': ('0.1.0', 1401044052), './dependencies_history\\alfy32_codeathon.json': ('0.0.1', 1398534943), './dependencies_history\\allevo_nodejs-travis-test.json': ('1.0.0', 1397818572), './dependencies_history\\AntonTimiskov_grunt-jasmine-phantomjs.json': ('0.1.0', 1391532356), './dependencies_history\\asleepwalker_jquery-ui.autocomplete.match.json': ('1.0.2', 1487278751), './dependencies_history\\awesomeo3000_arbybarbie.json': ('0.0.1', 1417472881), './dependencies_history\\bingpoint_my-first-app.json': ('0.1.0', 1417633654), './dependencies_history\\bosgood_depot.json': ('0.0.1', 1407731737), './dependencies_history\\brutalhonesty_wigle.js.json': ('0.0.1', 1415645452), './dependencies_history\\bsides_charsheet.json': ('0.0.0', 1400522811), './dependencies_history\\cgole_books.json': ('0.0.0', 1409170973), './dependencies_history\\concord-consortium_teaching-teamwork.json': ('1.0.1', 1476807202), './dependencies_history\\cranx_vm-launcher.json': ('0.0.0', 1419883175), './dependencies_history\\daveross_arrive-js.json': ('Unidentified', 1416114927), './dependencies_history\\designedbyscience_progressive-retina-js.json': ('1.0.0', 1397664848), './dependencies_history\\DevCodela_Curso-Backbonejs.json': ('0.0.1', 1391744227), './dependencies_history\\dmodalek_Awesome-Theme.json': ('1.0.0', 1414772737), './dependencies_history\\dominictarr_npmd-reverse-resolve.json': ('0.0.0', 1405890470), './dependencies_history\\Dyalog_ride.json': ('Unidentified', 1408710017), './dependencies_history\\efsharp_mongoose-snake-to-camel.json': ('0.3.0', 1519880637), './dependencies_history\\ElderMael_js-backbone-course.json': ('0.0.1', 1402708792), './dependencies_history\\Elisha4700_web-dev-db.json': ('0.1.2', 1391488314), './dependencies_history\\ergang_iBeaconNode.json': ('0.0.1', 1395354083), './dependencies_history\\erlikh_lzd_test.json': ('0.0.1', 1389869021), './dependencies_history\\esaari_Thinkful-node.js.json': ('1.0.0', 1414360718), './dependencies_history\\eunicel_spellcheck.json': ('0.0.0', 1413274939), './dependencies_history\\fatalaa_exchange.json': ('0.0.1', 1404179494), './dependencies_history\\fatihcode_weather.json': ('2.0.0', 1489544802), './dependencies_history\\fduffeal_angulartv.json': ('Unidentified', 1377581990), './dependencies_history\\fendyg_weightwatcher-client.json': ('0.0.0', 1397254750), './dependencies_history\\fevrcoding_wok.json': ('7.1.0', 1530007034), './dependencies_history\\freddielore_paginate.json': ('1.0.1', 1551102680), './dependencies_history\\Frozenfire92_ember-pikaday.json': ('0.1.8', 1419370472), './dependencies_history\\fsamin_nora.js.json': ('Unidentified', 1410091600), './dependencies_history\\gangleri_missing.json': ('0.0.1', 1395096174), './dependencies_history\\giles-t_instygram.json': ('0.0.1', 1392193686), './dependencies_history\\hackerspace-bootstrap_strichliste.json': ('1.7.0', 1518075434), './dependencies_history\\hexojs_hexo-deployer-heroku.json': ('0.1.2', 1501165929), './dependencies_history\\holyspecter_node_hangman.json': ('0.0.1', 1401650314), './dependencies_history\\iamnoah_mu.json': ('0.1.0', 1412792676), './dependencies_history\\icagstrout_optimusjs.json': ('Unidentified', 1393883382), './dependencies_history\\incrediblesound_predict-likes.json': ('0.0.4', 1400466390), './dependencies_history\\innovateboliu_SSNoC.json': ('1.0.0', 1398286061), './dependencies_history\\intuitivcloud_inturn.json': ('1.0.1', 1411308960), './dependencies_history\\itsgoingd_netmon.json': ...
