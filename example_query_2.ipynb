# %%
import json, glob, os, statistics as st

contributor_json_list = glob.glob(os.path.join('./contributors', '*.json'))
top_contributor_list = dict()

for contributor_file in contributor_json_list:
    with open(contributor_file) as f: json_obj = json.loads(f.read())
    if(len(json_obj) == 0 or type(json_obj[0]) != dict): continue
    top_contributor = sorted(json_obj, key=lambda user: -user['contributions'])[0]
    top_contributor_list[contributor_file] = top_contributor
print(top_contributor_list)
# Out:
# {'./contributors\\aaronthomas_aaronthomas.co.uk.json': {'login': 'aaronthomas', 'id': 1419558, 'node_id': 'MDQ6VXNlcjE0MTk1NTg=', 'avatar_url': 'https://avatars0.githubusercontent.com/u/1419558?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aaronthomas', 'html_url': 'https://github.com/aaronthomas', 'followers_url': 'https://api.github.com/users/aaronthomas/followers', 'following_url': 'https://api.github.com/users/aaronthomas/following{/other_user}', 'gists_url': 'https://api.github.com/users/aaronthomas/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aaronthomas/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aaronthomas/subscriptions', 'organizations_url': 'https://api.github.com/users/aaronthomas/orgs', 'repos_url': 'https://api.github.com/users/aaronthomas/repos', 'events_url': 'https://api.github.com/users/aaronthomas/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aaronthomas/received_events', 'type': 'User', 'site_admin': False, 'contributions': 10}, './contributors\\abramz_gulp-render-react.json': {'login': 'abramz', 'id': 4075481, 'node_id': 'MDQ6VXNlcjQwNzU0ODE=', 'avatar_url': 'https://avatars2.githubusercontent.com/u/4075481?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/abramz', 'html_url': 'https://github.com/abramz', 'followers_url': 'https://api.github.com/users/abramz/followers', 'following_url': 'https://api.github.com/users/abramz/following{/other_user}', 'gists_url': 'https://api.github.com/users/abramz/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/abramz/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/abramz/subscriptions', 'organizations_url': 'https://api.github.com/users/abramz/orgs', 'repos_url': 'https://api.github.com/users/abramz/repos', 'events_url': 'https://api.github.com/users/abramz/events{/privacy}', 'received_events_url': 'https://api.github.com/users/abramz/received_events', 'type': 'User', 'site_admin': False, 'contributions': 16}, './contributors\\Ahineya_jsdv.json': {'login': 'Ahineya', 'id': 2745520, 'node_id': 'MDQ6VXNlcjI3NDU1MjA=', 'avatar_url': 'https://avatars3.githubusercontent.com/u/2745520?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Ahineya', 'html_url': 'https://github.com/Ahineya', 'followers_url': 'https://api.github.com/users/Ahineya/followers', 'following_url': 'https://api.github.com/users/Ahineya/following{/other_user}', 'gists_url': 'https://api.github.com/users/Ahineya/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Ahineya/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Ahineya/subscriptions', 'organizations_url': 'https://api.github.com/users/Ahineya/orgs', 'repos_url': 'https://api.github.com/users/Ahineya/repos', 'events_url': 'https://api.github.com/users/Ahineya/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Ahineya/received_events', 'type': 'User', 'site_admin': False, 'contributions': 19}, './contributors\\akhoury_nodebb-plugin-import-xenforo.json': {'login': 'akhoury', 'id': 1398375, 'node_id': 'MDQ6VXNlcjEzOTgzNzU=', 'avatar_url': 'https://avatars3.githubusercontent.com/u/1398375?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/akhoury', 'html_url': 'https://github.com/akhoury', 'followers_url': 'https://api.github.com/users/akhoury/followers', 'following_url': 'https://api.github.com/users/akhoury/following{/other_user}', 'gists_url': 'https://api.github.com/users/akhoury/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/akhoury/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/akhoury/subscriptions', 'organizations_url': 'https://api.github.com/users/akhoury/orgs', 'repos_url': 'https://api.github.com/users/akhoury/repos', 'events_url': 'https://api.github.com/users/akhoury/events{/privacy}', 'received_events_url': 'https://api.github.com/users/akhoury/received_events', 'type': 'User ...
